# %%
# %%file config.json
# {
#     "app_id": "", //skywayのアプリケーションID //skyway application ID
#     "secret_key": "", //skywayのシークレットキー // skyway secret key
#     "username": "", //TCP Exposerのユーザー名 //TCP Exposer username
#     "sub_domain": "", //TCP Exposerのサブドメイン //TCP Exposer subdomain
#     "sub_domain2": "", //TCP Exposerのサブドメイン2つ目 //TCP Exposer subdomain2
#     "ssh_password": "", //TCP ExposerのSSHパスワード //TCP Exposer SSH password
#     "port": 19132, // websocketをlistenするポート //Port to listen
#     "web_port": 8000, // 近接vcのwebサイトと接続するポート // Port to connect website
#     "proximity": true, //近接VCのtrue:有効/false:無効(デフォルトはtrue) //Proximity VC true:enable/false:disable (default: true)
#     "spectator": true, //スペクテイターとVCを分けるかtrue:有効/false:無効(デフォルトはtrue) //Separate Spectator and VC true:enable/false:disable (default: true)
#     "password": false, //接続時のパスワードの有無(デフォルトはfalse) //Password in connection (default: false)
#     "distance": 6, // 声の届く最大距離(デフォルトは6) //Max distance of sound (default: 6)
#     "lang": "ja" //言語(ja:日本語, en:英語) //Language (ja:Japanese, en:English)
# }
# Out:
# Writing config.json

# %%
# %%file package.json
# {
#   "name": "socket-be",
#   "version": "1.2.3",
#   "description": "This is a tool to connect with MinecraftBE via websocket easier.",
#   "main": "src/index.js",
#   "types": "typings/index.d.ts",
#   "scripts": {
#     "test": "node test.js",
#     "lint": "eslint ./src/ --ext .js,.jsx,.ts,.tsx & tsc"
#   },
#   "dependencies": {
#     "@discordjs/voice": "^0.18.0",
#     "discord.js": "^14.18.0",
#     "express": "^4.19.2",
#     "flatted": "^3.3.3",
#     "fs": "^0.0.1-security",
#     "json5": "^2.2.3",
#     "moment-timezone": "^0.5.41",
#     "path": "^0.12.7",
#     "socket-be": "^2.0.1",
#     "wanakana": "^5.3.1",
#     "ws": "^8.13.0"
#   },
#   "devDependencies": {
#     "eslint": "^8.39.0",
#     "typescript": "^5.0.4"
#   },
#   "author": "tutinoko2048",
#   "license": "MIT",
#   "bugs": {
#     "url": "https://github.com/tutinoko2048/SocketBE/issues"
#   }
# }
# Out:
# Writing package.json

# %%
# !npm install -g npm@11.4.1
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb
# !npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# removed 9 packages, and changed 106 packages in 10s
# ⠦
# ⠦25 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦--2025-06-14 15:35:29--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.6.0/cloudflared-linux-amd64.deb [following]
# --2025-06-14 15:35:30--  https://github.com/cloudflare/cloudflared/releases/download/2025.6.0/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import requests
import os

cloudflare_worker_url = "https://hidden-waterfall-b30f.kkr1212.workers.dev//js-code"

output_file_name = "index.js"

try:
    response = requests.get(cloudflare_worker_url)

    response.raise_for_status()

    fetched_code = response.text
    with open(output_file_name, "w", encoding="utf-8") as f:
        f.write(fetched_code)

    print("✅ 成功しました！\n✅ success")
except requests.exceptions.HTTPError as http_err:
    print(f"❌ HTTPエラーが発生しました: {http_err}")
    print(f"レスポンス内容: {response.text if 'response' in locals() else 'N/A'}")
except requests.exceptions.RequestException as req_err:
    print(f"❌ リクエストエラーが発生しました: {req_err}")
except IOError as io_err:
    print(f"❌ ファイル書き込みエラーが発生しました ({output_file_name}): {io_err}")
except Exception as e:
    print(f"❌ 予期せぬエラーが発生しました: {e}")
# Out:
# ✅ 成功しました！
# ✅ success

# %%
# 1️⃣ 既存の node index.js を止める（特定の index.js に限定）
# !ps aux | grep '[n]ode index.js' | awk '{print $2}' | xargs -r kill -9

# 2️⃣ Node.js をバックグラウンドで再起動、PID を記録
import subprocess

# Node.jsをバックグラウンドで起動（標準出力・エラーはserver.logにリダイレクト）
with open("server.log", "w") as log_file:
    process = subprocess.Popen(
        ["node", "index.js"],
        stdout=log_file,
        stderr=log_file
    )

print(f"Node.js started with PID {process.pid}")

# !echo $! > node.pid

import time
import threading
import datetime

def keep_alive():
    while True:
            now = datetime.datetime.now()
            print(now)
            print("Keeping session alive...")
            time.sleep(150)  # 分間隔で出力

                    # バックグラウンドスレッドを起動
thread = threading.Thread(target=keep_alive, daemon=True)  # daemon=True でバックグラウンド実行
thread.start()
print("バックグラウンドでセッションを維持中...")

import subprocess
import re
import threading
import time
import requests # HTTPリクエスト用ライブラリ
import os

# --- json5 ライブラリのインストール (コメント付きJSON対応のため) ---
print("starting...")
install_json5_proc = subprocess.run(['pip', 'install', 'json5'], capture_output=True, text=True, check=False)
import json5 as json # 標準のjsonの代わりにjson5をjsonという名前でインポート


# --- SSHトンネル用関数 (tcpexposer.com) - 2トンネル対応 ---
def run_ssh_tunnels_with_password(config, ssh_password_from_secret):
    ssh_password = ssh_password_from_secret
    # (関数内容は変更なしのため省略)
    password_source_msg = "Colab Secrets"

    if not ssh_password:
        if 'ssh_password' in config and str(config.get('ssh_password', '')).strip():
            ssh_password = str(config.get('ssh_password', '')).strip()
            password_source_msg = "config.json (パスワードの平文保存は非推奨)"
        else:
            print("エラー: SSHパスワードがColab Secretsにもconfig.jsonにも有効な値で設定されていません。")
            return False

    username = str(config.get('username', '')).strip()
    if not username:
        print("エラー: SSHトンネルに必要な 'username' がconfig.jsonに設定されていません。")
        return False

    install_update = subprocess.run(['apt-get', 'update'], capture_output=True, text=True, check=False)
    if install_update.returncode != 0: print(f"apt-get updateに失敗: {install_update.stderr}")
    install_sshpass = subprocess.run(['apt-get', 'install', '-y', 'sshpass'], capture_output=True, text=True, check=False)
    if install_sshpass.returncode != 0:
        print(f"sshpassのインストールに失敗: {install_sshpass.stderr}")
        print("SSHトンネルの実行を中止します。")
        return False

    tunnel_configs = []
    sub_domain1 = str(config.get('sub_domain', '')).strip()
    web_port1 = str(config.get('web_port', '')).strip()
    if sub_domain1 and web_port1:
        tunnel_configs.append({
            "name": f"RoomID: {sub_domain1}\nURL：https://proximity-vc-mcbe.pages.dev?roomid={sub_domain1}",
            "sub_domain": sub_domain1,
            "local_port": web_port1
        })
    elif sub_domain1 or web_port1:
        print(f"警告: SSHトンネル1の設定が不完全です (sub_domain='{sub_domain1}', web_port='{web_port1}')。このトンネルはスキップされます。")

    sub_domain2_val = str(config.get('sub_domain2', '')).strip()
    port_val = str(config.get('port', '')).strip()
    if sub_domain2_val and port_val:
        tunnel_configs.append({
            "name": f"\nこのコマンドを実行して接続：/connect {sub_domain2_val}.tcpexposer.com\nRun this command to connect: /connect {sub_domain2_val}.tcpexposer.com",
            "sub_domain": sub_domain2_val,
            "local_port": port_val
        })
    elif sub_domain2_val or port_val:
        print(f"警告: SSHトンネル2の設定が不完全です (sub_domain2='{sub_domain2_val}', port='{port_val}')。このトンネルはスキップされます。")

    if not tunnel_configs:
        print("設定可能なSSHトンネルがありません。")
        return False

    active_ssh_processes = []

    for tc in tunnel_configs:
        ssh_command = [
            'sshpass', '-p', ssh_password, 'ssh',
            '-R', f'{tc["sub_domain"]}:80:localhost:{tc["local_port"]}',
            f'{username}@tcpexposer.com',
            '-N', '-o', 'StrictHostKeyChecking=no', '-o', 'UserKnownHostsFile=/dev/null',
            '-o', 'ExitOnForwardFailure=no', '-o', 'ServerAliveInterval=60', '-o', 'ConnectTimeout=10'
        ]
        try:
            proc = subprocess.Popen(ssh_command, text=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            active_ssh_processes.append({'process': proc, 'name': tc['name']})
            print(f"{tc['name']}")
        except Exception as e:
            print(f"{tc['name']} の起動に失敗しました: {e}")

    if not active_ssh_processes:
        print("起動できたSSHトンネルプロセスがありません。")
        return False
    print("✅ start")
    try:
        while True:
            all_terminated = True
            for p_info in active_ssh_processes:
                proc = p_info['process']
                if proc.poll() is None:
                    all_terminated = False
                else:
                    stdout, stderr = proc.communicate()
                    if stdout: print(f"  [{p_info['name']} STDOUT]:\n{stdout.strip()}")
                    if stderr: print(f"  [{p_info['name']} STDERR]:\n{stderr.strip()}")
                    active_ssh_processes = [p for p in active_ssh_processes if p['process'].pid != proc.pid]
                    if not active_ssh_processes : all_terminated = True
            if all_terminated and not active_ssh_processes: break
            if not active_ssh_processes and tunnel_configs:
                if not any(p_info['process'].poll() is None for p_info in active_ssh_processes):
                    print("アクティブなSSHトンネルプロセスがなくなりました。")
                    break
            if not active_ssh_processes:
                print("監視対象のSSHトンネルがなくなりました。")
                break
            time.sleep(5)
    except KeyboardInterrupt:
        print("\nCtrl+C が検出されました。SSHトンネルを終了します...")
    finally:
        for p_info in active_ssh_processes:
            if p_info['process'].poll() is None: p_info['process'].terminate()
        time.sleep(1)
        for p_info in active_ssh_processes:
            if p_info['process'].poll() is None: p_info['process'].kill()
        print('\n\033[31m' + "終了しました\n再度起動する場合は最初から実行しなおしてください\nFinished\nTo start the program again, rerun it from the beginning." +'\033[0m')
    return True


# --- Cloudflareトンネル用関数 ---
def run_cloudflared_tunnels(config):
    CLOUDFLARE_BASE_DOMAIN = "trycloudflare.com"
    cloudflared_command = "cloudflared"

    try:
        subprocess.run([cloudflared_command, '--version'], check=True, capture_output=True, text=True)
    except (subprocess.CalledProcessError, FileNotFoundError):
        pass

    default_cf_port1 = "19132"
    default_cf_port2 = "8000"
    cf_port1_from_config = str(config.get('port', default_cf_port1)).strip()
    local_port_for_ssh = cf_port1_from_config if cf_port1_from_config else default_cf_port1
    cf_port2_from_config = str(config.get('web_port', default_cf_port2)).strip()
    local_port_for_cloudflared = cf_port2_from_config if cf_port2_from_config else default_cf_port2

    proc1, proc2 = None, None
    lhr_url1 = None

    try:
        ssh_command_for_lhr = [
            'ssh', '-o', 'LogLevel=ERROR', '-o', 'StrictHostKeyChecking=no',
            '-o', 'UserKnownHostsFile=/dev/null', '-o', 'ServerAliveInterval=30',
            '-o', 'ServerAliveCountMax=2', '-o', 'ConnectTimeout=20',
            '-R', f'80:localhost:{local_port_for_ssh}', 'nokey@localhost.run'
        ]
        proc1 = subprocess.Popen(
            ssh_command_for_lhr, stdin=subprocess.DEVNULL, stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT, text=True, universal_newlines=True, bufsize=1
        )
        if local_port_for_cloudflared:
            try:
                subprocess.run([cloudflared_command, '--version'], check=True, capture_output=True, text=True)
                proc2 = subprocess.Popen(
                    [cloudflared_command, 'tunnel', '--url', f'localhost:{local_port_for_cloudflared}', '--no-autoupdate'],
                    stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, universal_newlines=True
                )
            except (subprocess.CalledProcessError, FileNotFoundError): proc2 = None
            except Exception: proc2 = None
    except FileNotFoundError:
        print('\n\033[31m' + "エラーが発生しました (sshコマンド等が見つからない可能性)\n最初から実行しなおしてください\nAn error has occurred (ssh command might be missing)\nPlease run it again from the beginning." +'\033[0m')
        if proc1 and proc1.poll() is None: proc1.kill()
        if proc2 and proc2.poll() is None: proc2.kill()
        return False
    except Exception as e:
        print('\n\033[31m' + f"トンネルプロセス起動時にエラーが発生しました: {e}\n最初から実行しなおしてください\nAn error occurred while starting tunnel process: {e}\nPlease run it again from the beginning." +'\033[0m')
        if proc1 and proc1.poll() is None: proc1.kill()
        if proc2 and proc2.poll() is None: proc2.kill()
        return False

    # --- wait_for_tunnel_host_id 関数の修正 ---
    def wait_for_tunnel_host_id(proc, tunnel_name):
        if proc is None or proc.stdout is None:
            return None
        timeout_seconds = 60  # タイムアウトを60秒に延長
        start_time = time.time()
        line_count = 0
        max_lines = 150  # 読み取り行数の上限を増加

        # URLを抽出するための正規表現 (変更なし)
        url_pattern = re.compile(r'https://([a-zA-Z0-9-]+)\.trycloudflare\.com')

        # cloudflaredが出力する可能性のあるエラー/失敗メッセージのパターン
        error_patterns = [
            "Failed to establish tunnel", "failed to connect to origin", "failed to create tunnel",
            "error=", "unable to connect to the origin", "Service not found",
            "Tunnel credentials file doesn't exist", "Invalid Argo Tunnel token",
            "is not a recognized command", "connection refused"
            # 必要に応じて他のエラーメッセージも追加
        ]

        for line in proc.stdout:
            if time.time() - start_time > timeout_seconds or line_count > max_lines:
                print(f"[{tunnel_name}] URL取得タイムアウトまたは行数上限到達。")
                break
            line_stripped = line.strip()
            # デバッグ用: print(f"DEBUG_CF [{tunnel_name}]: {line_stripped}") # 必要に応じてコメント解除して確認

            match = url_pattern.search(line_stripped)
            if match:
                host_id = match.group(1)
                return host_id # URLが見つかったらホストIDを返す

            # エラーパターンのチェック
            for err_pattern in error_patterns:
                if err_pattern.lower() in line_stripped.lower(): # 大文字小文字を区別せずにチェック
                    print(f"[{tunnel_name}] トンネル確立失敗の兆候 ({err_pattern}): {line_stripped}")
                    return None # エラーを検出したらNoneを返して関数を終了

            line_count += 1

        # ループがタイムアウトまたは行数上限で終了した場合
        print(f"[{tunnel_name}] 出力からトンネルホストIDを見つけられませんでした。")
        return None
    # --- wait_for_tunnel_host_id 関数の修正ここまで ---


    def send_keep_alive(host_id, base_domain, tunnel_name, interval_seconds=180):
        # (関数内容は変更なしのため省略)
        if not host_id:
            return
        url = f"https://{host_id}.{base_domain}"
        while True:
            try:
                requests.head(url, timeout=15)
            except requests.exceptions.RequestException:
                pass
            except Exception:
                pass
            time.sleep(interval_seconds)


    if proc1 and proc1.stdout:
        timeout_seconds_lhr = 30; start_time_lhr = time.time()
        while True:
            if time.time() - start_time_lhr > timeout_seconds_lhr: break
            line_lhr = "";
            try:
                line_lhr = proc1.stdout.readline()
                if not line_lhr: break
            except Exception: break
            line_lhr_stripped = line_lhr.strip()
            match_lhr = re.search(r'https?://([a-zA-Z0-9-]+)\.lhr\.life', line_lhr_stripped)
            if match_lhr:
                lhr_url1 = match_lhr.group(0)
                if not lhr_url1.startswith('https'): lhr_url1 = 'https://' + lhr_url1.split("://",1)[1]
                break
            error_keywords = ["remote port forwarding failed", "could not request remote forwarding", "permission denied", "error"]
            if any(keyword in line_lhr_stripped.lower() for keyword in error_keywords): break

    host_id2 = None
    if proc2: host_id2 = wait_for_tunnel_host_id(proc2, f"CF_Tunnel_2 (localhost:{local_port_for_cloudflared})")

    keep_alive_threads = []
    if lhr_url1:
        lhr_host_match = re.search(r'https?://([^/]+)', lhr_url1)
        if lhr_host_match:
            lhr_hostname1 = lhr_host_match.group(1)
            print(f"\nこのコマンドを実行して接続（5分以内）：/connect {lhr_hostname1}\nRun this command to connect(within 5 minutes): /connect {lhr_hostname1}")

    if host_id2:
        full_url2_display = f"https://{host_id2}.{CLOUDFLARE_BASE_DOMAIN}"
        print(f"RoomID：{host_id2}")
        print(f"URL：https://proximity-vc-mcbe.pages.dev?roomid={host_id2}")
        thread2 = threading.Thread(target=send_keep_alive, args=(host_id2, CLOUDFLARE_BASE_DOMAIN, f"CF_Tunnel_2_KeepAlive({local_port_for_cloudflared})"), daemon=True)
        keep_alive_threads.append(thread2)
        thread2.start()

    if not lhr_url1 and not host_id2:
        print("両方のCloudflareトンネルURLの取得に失敗したため、プログラムを終了します。")
        if proc1 and proc1.poll() is None: proc1.terminate(); time.sleep(0.1); proc1.kill()
        if proc2 and proc2.poll() is None: proc2.terminate(); time.sleep(0.1); proc2.kill()
        return False

    print("✅ start")
    try:
        while True:
            p1_active = bool(lhr_url1 and proc1 and proc1.poll() is None)
            p2_active = bool(host_id2 and proc2 and proc2.poll() is None)
            if (lhr_url1 or host_id2) and not (p1_active or p2_active):
                print("アクティブなCloudflareトンネルプロセスがなくなりました."); break
            if not (lhr_url1 or host_id2) and not (p1_active or p2_active):
                 print("URL取得に失敗し、Cloudflareプロセスも終了しました."); break
            if keep_alive_threads and not any(t.is_alive() for t in keep_alive_threads):
                if not p1_active and not p2_active: # 両方のプロセスも終了している場合
                    print("全てのキープアライブスレッドが終了し、アクティブなトンネルもありません。メインループを終了します.")
                    break
            time.sleep(5)
    except KeyboardInterrupt:
        print("\nCtrl+C が検出されました。Cloudflareトンネルを終了します...")
    finally:
        procs_to_kill = []
        if proc1 and proc1.poll() is None: procs_to_kill.append(proc1)
        if proc2 and proc2.poll() is None: procs_to_kill.append(proc2)
        for p in procs_to_kill: p.terminate()
        time.sleep(1)
        for p in procs_to_kill:
            if p.poll() is None: p.kill()
        print('\n\033[31m' + "終了しました\n再度起動する場合は最初から実行しなおしてください。\nFinished\nTo start the program again, rerun it from the beginning." +'\033[0m')
    return True

# --- メイン処理 ---
def main():
    config = {}
    ssh_password_from_secret = ""
    use_ssh_tunnel_flag = False
    try:
        with open('config.json', 'r', encoding='utf-8') as f: config = json.load(f)
    except FileNotFoundError:
        print('\n\033[31m' + "'config.json' が見つかりません\n‘Config‘を実行してください" + '\033[0m'); print("'config.json' not found\nPlease run ‘Config’"); return
    except json.JSONDecodeError as e:
        print('\n\033[31m' + f"'config.json' の読み込みに失敗しました (JSON形式エラー)\nConfigを正しく記述してください\nFailed to read 'config.json' (JSON format error) \nPlease write Config correctly" + '\033[0m'); print(e); return
    except Exception as e:
        print('\n\033[31m' + f"config.jsonの処理中に予期せぬエラーが発生しました\n最初からやり直してくださいください\nAn unexpected error occurred while processing config.json \nPlease start over from the beginning." + '\033[0m'); print(e); return

    username_in_config = str(config.get('username', '')).strip()
    sub_domain1_in_config = str(config.get('sub_domain', '')).strip()
    web_port1_in_config = str(config.get('web_port', '')).strip()
    sub_domain2_in_config = str(config.get('sub_domain2', '')).strip()
    port_in_config = str(config.get('port', '')).strip()
    ssh_password_in_config = str(config.get('ssh_password', '')).strip()
    try:
        if 'google.colab' in str(type(userdata)): ssh_password_from_secret = userdata.get('SSH_PASSWORD')
    except Exception: ssh_password_from_secret = ""

    has_ssh_password = bool(ssh_password_from_secret or ssh_password_in_config)
    can_attempt_ssh_tunnel = username_in_config and has_ssh_password
    has_valid_ssh_tunnel_config = (sub_domain1_in_config and web_port1_in_config) or \
                                  (sub_domain2_in_config and port_in_config)
    if can_attempt_ssh_tunnel and has_valid_ssh_tunnel_config: use_ssh_tunnel_flag = True
    else:
        # このprint文はユーザーが最近追加したもののようですので、残しておきます。
        print("\nConfigにTCPexposerの設定がありません\nランダムドメインで実行します\nNo TCPexposer setting in Config\nRun in random domain")


    if use_ssh_tunnel_flag: run_ssh_tunnels_with_password(config, ssh_password_from_secret)
    else: run_cloudflared_tunnels(config)

if __name__ == '__main__':
    main()
# Out:
# 2025-06-14 15:36:25.297980バックグラウンドでセッションを維持中...
#
# Keeping session alive...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-3432658863> in <cell line: 0>()
#      23 print("バックグラウンドでセッションを維持中...")
#      24
# ---> 25 from pynput.mouse import Controller, Button
#      26 import time
#      27
#
# /usr/local/lib/python3.11/dist-packages/pynput/__init__.py in <module>
#      38
#      39
# ---> 40 from . import keyboard
#      41 from . import mouse
#
# /usr/local/lib/python3.11/dist-packages/pynput/keyboard/__init__.py in <module>
#      29
#      30
# ---> 31 backend = backend(__name__)
#      32 KeyCode = backend.KeyCode
#      33 Key = backend.Key
#
# /usr/local/lib/python3.11/dist-packages/pynput/_util/__init__.py in backend(package)
#      76                 resolutions.append(RESOLUTIONS[module])
#      77
# ...

# %%
# !cat server.log
# Out:
# cat: server.log: No such file or directory
